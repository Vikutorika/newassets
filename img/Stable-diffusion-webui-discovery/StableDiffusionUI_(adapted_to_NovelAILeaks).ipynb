# %% [markdown]
# Clone webui repository

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 14358, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 14358 (delta 60), reused 82 (delta 34), pack-reused 14231
# Receiving objects: 100% (14358/14358), 26.39 MiB | 39.85 MiB/s, done.
# Resolving deltas: 100% (10012/10012), done.
# /content/stable-diffusion-webui

# %% [markdown]
# Download the model from NovelAILeaks.

# %%
# !mkdir -p /content/stable-diffusion-webui/models/Stable-diffusion /content/stable-diffusion-webui/models/hypernetworks
# %cd /content/stable-diffusion-webui/models/Stable-diffusion/

# 7G animefull-final-latest (may not work)
# !wget https://share4nothing.cf/NovelAI/animefull-final-latest.ckpt -O model.ckpt

# 4G animefull-final-pruned
# !wget https://share4nothing.cf/NovelAI/animefull-final-pruned.ckpt -O model.ckpt

# Install VAE Weights (optional)
# !wget https://share4nothing.cf/NovelAI/assets/anime.vae.pt

# Install hypernetwork （optional)
# !curl -L https://share4nothing.cf/NovelAI/assets/_modules.tar | tar x -C /content/stable-diffusion-webui/models/hypernetworks

# Install custom embeddings (modified, optional)
# !curl -L https://share4nothing.cf/NovelAI/assets/embeddings.tar | tar x -C /content/stable-diffusion-webui/embeddings
# Out:
# /content/stable-diffusion-webui/models/Stable-diffusion
# --2023-01-15 15:42:00--  https://share4nothing.cf/NovelAI/animefull-final-pruned.ckpt
# Resolving share4nothing.cf (share4nothing.cf)... 50.31.246.2
# Connecting to share4nothing.cf (share4nothing.cf)|50.31.246.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://gamernotitle-my.sharepoint.com/personal/admin_bili33_top/_layouts/15/download.aspx?UniqueId=21d9856a-49e8-47ce-938d-07aa33b674ba&Translate=false&tempauth=eyJ0eXAiOiJKV1QiLCJhbGciOiJub25lIn0.....V2JYN2NIZ21rdDJmWU9BanJqQnVIYTgwdDdjenl2dkNrUFRJaXBYTHVNWT0&ApiVersion=2.0 [following]
# --2023-01-15 15:42:01--  https://gamernotitle-my.sharepoint.com/personal/admin_bili33_top/_layouts/15/download.aspx?UniqueId=21d9856a-49e8-47ce-938d-07aa33b674ba&Translate=false&tempauth=eyJ0eXAiOiJKV1QiLCJhbGciOiJub25lIn0.....V2JYN2NIZ21rdDJmWU9BanJqQnVIYTgwdDdjenl2dkNrUFRJaXBYTHVNWT0&ApiVersion=2.0
# ...

# %% [markdown]
# Launch web ui. You will get a link to nnn.gradio.app, follow it.
#
# Commandline arguments are:
#   - `--share` - create online gradio.app link
#   - `--gradio-debug` - print outputs to console
#   - `--gradio-auth me:qwerty` - add authentication to gradio: username me, password qwerty

# %%
# %cd /content/stable-diffusion-webui
# !COMMANDLINE_ARGS="--share --gradio-debug --medvram --disable-safe-unpickle" REQS_FILE="requirements.txt" python launch.py
# Out:
# /content/stable-diffusion-webui
# Python 3.8.16 (default, Dec  7 2022, 01:12:13)
# [GCC 7.5.0]
# Commit hash: ebfdd7baeb660ec66f78e1a0e5e45442025f262d
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug --medvram --disable-safe-unpickle
# No module 'xformers'. Proceeding without it.
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading: 100% 939k/939k [00:00<00:00, 8.88MB/s]
# Downloading: 100% 512k/512k [00:00<00:00, 5.68MB/s]
# Downloading: 100% 389/389 [00:00<00:00, 575kB/s]
# ...

# %% [markdown]
# commands for ***after*** you have gotten done with a session
# ============================================================================

# %% [markdown]
# Zip images for downloading on local drive (click the folder icon on the left, the one below {x})

# %%
# !zip -r /content/stable-diffusion-webui /content/stable-diffusion-webui/outputs

# %% [markdown]
# Save images to Google Drive **Warning: this will cause google to scan your drive, so if you intend to use this and worry about that kind of stuff, probablly just set this up on a clean account that's just for this colab**

# %%
from google.colab import drive # type: ignore

try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
except:
   print("...error mounting drive or with drive path variables")

# !cp -r "/content/stable-diffusion-webui/outputs" "/content/drive/MyDrive"
